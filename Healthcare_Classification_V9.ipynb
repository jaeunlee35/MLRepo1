# %%
import numpy as np
import tensorflow as tf
import itertools
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

########################
# Data

def load_csv(file_path):
    # 첫 번째 행(헤더) 읽기
    with open(file_path, 'r') as f:
        header = f.readline().strip().split(',')
    
    # 데이터 로드 (첫 번째 행 제외)
    data = np.loadtxt(file_path, delimiter=',', skiprows=1)
    
    # 'fetal_health'를 타겟 변수로 설정 (마지막 열)
    x_data = data[:, :-1]  # 마지막 열을 제외한 모든 열 (입력 변수)
    y_data = data[:, -1].astype(int)  # 마지막 열 (타겟 변수)
    
    # 타겟 변수를 원-핫 인코딩으로 변환
    with tf.Session() as sess:
        y_data = tf.one_hot(y_data - 1, depth=3).eval()
    
    feature_names = header[:-1]  # 마지막 열 이름은 제외
    
    print(f'1. CSV Loading')  # 대제목 출력
    print(f"x_data shape: {x_data.shape}")
    print(f"y_data shape: {y_data.shape}")
    print(f"Feature names: {feature_names}")
    print()
    
    return x_data, y_data, feature_names

def split_data(x_data, y_data):
    # 데이터셋을 학습, 검증, 테스트로 나누기
    # random_state는 Seed값으로 동일한 분할 결과를 얻기 위해 사용
    # 전체 데이터의 20%를 테스트 데이터로 사용
    x_temp, x_test, y_temp, y_test = train_test_split(
        x_data, y_data, test_size=0.2, random_state=42, stratify=y_data.argmax(axis=1))
    # 테스트 데이터를 제외한 나머지 데이터의 12.5%를 검증 데이터로 사용, 
    # 나머지를 학습 데이터로 사용
    x_train, x_val, y_train, y_val = train_test_split(
        x_temp, y_temp, test_size=0.125, random_state=42, stratify=y_temp.argmax(axis=1))
    
    # 표준화 (스케일링)
    sc = StandardScaler()
    # 학습 데이터에 fit_transform을 사용하여 평균과 표준편차를 계산하고 데이터를 표준화
    x_train = sc.fit_transform(x_train)
    # 검증 및 테스트 데이터에는 학습 데이터의 평균과 표준편차를 사용하여 동일하게 표준화
    x_val = sc.transform(x_val)
    x_test = sc.transform(x_test)
    
    return x_train, x_val, x_test, y_train, y_val, y_test

########################
# Data Analysis

def draw_data_distributions(data, feature_names, title, num_print_columns=3):
    print(f'2. Data Analysis')  # 대제목 출력
    num_columns = data.shape[1]
    num_rows = (num_columns + num_print_columns - 1) // num_print_columns

    fig, axes = plt.subplots(num_rows + 1, num_print_columns, figsize=(15, 5 * (num_rows + 1)), 
                                gridspec_kw={'height_ratios': [0.3] + [2] * num_rows})

    # 소제목을 첫 번째 행에 왼쪽 정렬로 추가
    axes[0, 0].text(0, 0.5, f'{title}', fontsize=16, ha='left', va='center')
    for j in range(num_print_columns):
        axes[0, j].axis('off')

    # 각 행별로 최대 y값을 계산하여 동일한 y축 범위 설정
    for row in range(0, num_rows):
        # 해당 행의 모든 그래프에 대한 최대 y값 찾기
        max_y = 0
        for col in range(num_print_columns):
            i = row * num_print_columns + col
            if i < num_columns:
                counts, _ = np.histogram(data[:, i], bins=30)
                current_max = counts.max()
                if current_max > max_y:
                    max_y = current_max
        
        # 각 그래프에 히스토그램 그리기 및 y축 범위 설정
        for col in range(num_print_columns):
            i = row * num_print_columns + col
            if i < num_columns:
                axe = axes[row+1, col]
                axe.hist(data[:, i], bins=30, color='skyblue', edgecolor='black')
                axe.set_title(f'{feature_names[i]}')
                axe.set_xlabel(f'{feature_names[i]}')
                axe.set_ylabel('Frequency')
                axe.set_ylim(0, max_y + max_y * 0.1)  # 최대 y값의 110%로 설정

    # 남은 빈 플롯 비활성화
    for i in range(num_columns, num_rows * num_print_columns):
        row = (i // num_print_columns) + 1
        col = i % num_print_columns
        figures[row, col].axis('off')

    plt.tight_layout()
    plt.show()

def draw_correlation_matrix(x, y, feature_names, title=None):
    # 입력 특성과 목표 변수를 결합
    data = np.hstack((x, y))
    
    # 상관계수 행렬 계산
    corr_matrix = np.corrcoef(data, rowvar=False)
    # 특성 수
    num_features = x.shape[1]

    feature_labels = feature_names + ['Target']
    
    # 히트맵 시각화
    plt.figure(figsize=(10, 8))
    im = plt.imshow(corr_matrix, cmap='coolwarm', interpolation='nearest')
    plt.colorbar(im, fraction=0.046, pad=0.04)
    
    # 축 레이블 설정 (제거)
    plt.xticks(range(num_features + 1), [])  # 열 이름 제거
    plt.yticks(range(num_features + 1), [])  # 행 이름 제거
    
    # 각 셀에 상관계수 표시
    for i in range(num_features + 1):
        for j in range(num_features + 1):
            text = f"{corr_matrix[i, j]:.2f}"
            plt.text(j, i, text,
                     ha="center", va="center", color="black")
    
    # 제목 설정
    if title:
        plt.title(title, pad=20)
    
    plt.tight_layout()
    plt.show()

########################
# Learning

def create_graph(optimizer, input_num, hidden_sizes, output_num):
    tf.reset_default_graph()  # 그래프 초기화
    
    x = tf.placeholder(tf.float32, [None, input_num], name='x')  # 입력 데이터 플레이스홀더
    y = tf.placeholder(tf.float32, [None, output_num], name='y')  # 레이블 데이터 플레이스홀더

    # 은닉층 생성
    layer_input = x
    layer_input_size = input_num

    for idx, hidden_size in enumerate(hidden_sizes):
        W_hidden = tf.Variable(tf.random_normal([layer_input_size, hidden_size], stddev=0.1),
                               name=f'W_hidden_{idx+1}')
        b_hidden = tf.Variable(tf.zeros([hidden_size]), name=f'b_hidden_{idx+1}')
        layer_output = tf.nn.relu(tf.matmul(layer_input, W_hidden) + b_hidden, name=f'relu_{idx+1}')

        # 다음 층을 위한 입력 업데이트
        layer_input = layer_output
        layer_input_size = hidden_size

    # 출력층
    W_output = tf.Variable(tf.random_normal([layer_input_size, output_num], stddev=0.1), name='W_output')
    b_output = tf.Variable(tf.zeros([output_num]), name='b_output')
    logits = tf.matmul(layer_input, W_output) + b_output

    prediction = tf.nn.softmax(logits, name='prediction')
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y, logits=logits), name='loss')
    train_step = optimizer.minimize(loss, name='train_step')

    # 정확도 계산
    correct_prediction = tf.equal(tf.argmax(prediction, 1), tf.argmax(y, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')

    return x, y, prediction, loss, train_step, accuracy

def execute_graph(x, y, prediction, loss, train_step, accuracy, data, epoch, batch_size):
    train_losses = []
    val_losses = []
    test_losses = []
    
    train_accuracies = []
    val_accuracies = []
    test_accuracies = []

    x_train, x_val, x_test, y_train, y_val, y_test = data
       
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())  # 변수 초기화
        for e in range(1, epoch + 1):
            # 학습 데이터 셔플
            permutation = np.random.permutation(len(x_train))
            x_train_shuffled = x_train[permutation]
            y_train_shuffled = y_train[permutation]

            num_batches = (len(x_train) + batch_size - 1) // batch_size
            for i in range(num_batches):
                start_idx = i * batch_size
                end_idx = min((i+1) * batch_size, len(x_train))
                batch_x = x_train_shuffled[start_idx:end_idx]
                batch_y = y_train_shuffled[start_idx:end_idx]
                sess.run(train_step, feed_dict={x: batch_x, y: batch_y})

            if e % 10 == 1:
                # 손실과 정확도 계산
                train_loss, train_acc = sess.run([loss, accuracy], feed_dict={x: x_train, y: y_train})
                val_loss, val_acc = sess.run([loss, accuracy], feed_dict={x: x_val, y: y_val})
                test_loss, test_acc = sess.run([loss, accuracy], feed_dict={x: x_test, y: y_test})
                
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                test_losses.append(test_loss)

                train_accuracies.append(train_acc)
                val_accuracies.append(val_acc)
                test_accuracies.append(test_acc)
                print(f'Epoch {e}, Training Loss: {train_loss:.4f}, Training Accuracy: {train_acc:.4f}, '
                      f'Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_acc:.4f}, '
                      f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}')

        # 최종 예측 저장
        predictions = sess.run(prediction, feed_dict={x: x_test})

    return train_losses, val_losses, test_losses, train_accuracies, val_accuracies, test_accuracies, predictions

def draw_loss_and_accuracy(axe, train_losses, val_losses, test_losses, 
                           train_accuracies, val_accuracies, test_accuracies, title=None, y_lim=None):
    if len(train_losses) > 0:
        epochs = range(1, len(train_losses) + 1)
        axe.plot(epochs, train_losses, label='Training Loss', color='blue')
        axe.plot(epochs, val_losses, label='Validation Loss', color='orange')
        axe.plot(epochs, test_losses, label='Test Loss', color='green', linestyle='--')
        axe.plot(epochs, train_accuracies, label='Training Accuracy', color='red', linestyle=':')
        axe.plot(epochs, val_accuracies, label='Validation Accuracy', color='purple', linestyle=':')
        axe.plot(epochs, test_accuracies, label='Test Accuracy', color='brown', linestyle='-.')
        axe.set_xlabel('Epochs')
        axe.set_ylabel('Loss / Accuracy')
        if title is not None:
            axe.set_title(f'{title}')
        axe.legend()
        axe.grid(True)
        if y_lim:
            axe.set_ylim(y_lim)

def format_param(param_name, param_value):
    if param_name == 'optimizer':
        return f"{param_name.replace('_', ' ').title()}: {param_value.__name__}"
    elif param_name == 'hidden_sizes':
        return f"{param_name.replace('_', ' ').title()}: {param_value}"
    else:
        return f"{param_name.replace('_', ' ').title()}: {param_value}"

def learn(data, param_grid):
    x_train, x_val, x_test, y_train, y_val, y_test = data
    best_report = None
    best_test_accuracy = -1

    # 모든 가능한 하이퍼파라미터 조합 생성
    param_keys = list(param_grid.keys())
    param_values = [param_grid[key] for key in param_keys]
    all_configurations = list(itertools.product(*param_values))
    print('3. Training Models')
    print(f"Total configurations: {len(all_configurations)}")

    # 하이퍼파라미터 중 가장 많은 옵션을 가진 것을 기준으로 컬럼 수 결정
    num_columns = max(len(options) for options in param_grid.values())
    num_rows = len(param_keys)

    # 시각화를 위한 구성 인덱스 수집
    plot_config_indices = {}
    for param_idx, key in enumerate(param_keys):
        options_length = len(param_grid[key])
        configs = []
        for idx in range(options_length):
            config_indices = [0] * len(param_keys)
            config_indices[param_idx] = idx
            configs.append(tuple(config_indices))
        plot_config_indices[param_idx] = configs

    # 모든 구성의 결과 저장
    results = {}
    for idx, config_values in enumerate(all_configurations):
        params = dict(zip(param_keys, config_values))
        config_indices = tuple(param_grid[key].index(value) for key, value in params.items())
        print(f"Training model {idx+1}/{len(all_configurations)} with parameters:")
        print(f"Config indices: {config_indices}")
        print(params)

        optimizer_class = params['optimizer']
        learning_rate = params['learning_rate']
        hidden_sizes = params['hidden_sizes']
        epoch = params['epoch']
        batch_size = params['batch_size']

        optimizer = optimizer_class(learning_rate=learning_rate)
        
        # 그래프 생성
        x, y, prediction, loss, train_step, accuracy = create_graph(
            optimizer, x_train.shape[1], hidden_sizes, y_train.shape[1])
        
        # 그래프 실행
        train_losses, val_losses, test_losses, train_accuracies, val_accuracies, \
        test_accuracies, predictions = execute_graph(
            x, y, prediction, loss, train_step, accuracy,
            (x_train, x_val, x_test, y_train, y_val, y_test), epoch, batch_size)

        # 최고 성능 모델 업데이트
        if test_accuracies[-1] > best_test_accuracy:
            best_test_accuracy = test_accuracies[-1]
            best_report = {
                "params": params,
                "train_losses": train_losses,
                "val_losses": val_losses,
                "test_losses": test_losses,
                "train_accuracies": train_accuracies,
                "val_accuracies": val_accuracies,
                "test_accuracies": test_accuracies,
                "predictions": predictions,
                "y_test": y_test
            }
            print(f"New best model found: Test Accuracy = {best_test_accuracy:.4f}\n")

        # 모든 구성의 결과 저장
        results[config_indices] = {
            "params": params,
            "train_losses": train_losses,
            "val_losses": val_losses,
            "test_losses": test_losses,
            "train_accuracies": train_accuracies,
            "val_accuracies": val_accuracies,
            "test_accuracies": test_accuracies,
        }

        print("-" * 80)

    # 지정된 구성을 시각화
    # 서브플롯 준비
    fig, axes = plt.subplots(num_rows, num_columns, figsize=(5 * num_columns, 5 * num_rows))
    plt.subplots_adjust(hspace=0.5)

    # 서브플롯이 2D 배열이 되도록 조정 (단일 행 또는 열인 경우)
    if num_rows == 1:
        axes = np.expand_dims(axes, axis=0)
    if num_columns == 1:
        axes = np.expand_dims(axes, axis=1)

    for param_idx, configs in plot_config_indices.items():
        # 각 행의 최대 손실 값 찾기
        max_loss = 0
        for config_indices in configs:
            result = results.get(config_indices)
            if result:
                current_max = max(result['train_losses'] + result['val_losses'] + result['test_losses'])
                if current_max > max_loss:
                    max_loss = current_max
        # y_lim 설정 (최대 손실 값의 110%)
        y_lim = (0, max_loss * 1.1) if max_loss > 0 else None

        for col_index, config_indices in enumerate(configs):
            row_index = param_idx
            ax = axes[row_index, col_index]

            result = results.get(config_indices)
            if result:
                param_name = param_keys[param_idx]
                param_value = param_grid[param_name][config_indices[param_idx]]
                formatted_title = format_param(param_name, param_value)
                draw_loss_and_accuracy(
                    ax,
                    result['train_losses'],
                    result['val_losses'],
                    result['test_losses'],
                    result['train_accuracies'],
                    result['val_accuracies'],
                    result['test_accuracies'],
                    title=formatted_title,
                    y_lim=y_lim
                )
            else:
                ax.axis('off')

    plt.tight_layout()
    plt.show()
    
    return best_report

########################
# Report

def generate_report(report):
    print('4. Conclusion')

    if report is None:
        print("No report to generate.")
        return
    
    params = report['params']
    print(f"[Best Parameters]")
    print(f"Optimizer: {params['optimizer'].__name__}")
    print(f"Learning rate: {params['learning_rate']}")
    print(f"Hidden sizes: {params['hidden_sizes']}")
    print(f"Batch size: {params['batch_size']}")
    print(f"Epoch: {params['epoch']}")
    print(f"Training loss: {report['train_losses'][-1]:.4f}")
    print(f"Validation loss: {report['val_losses'][-1]:.4f}")
    print(f"Test loss: {report['test_losses'][-1]:.4f}")
    print(f"Test Accuracy: {report['test_accuracies'][-1]:.4f}")

    # 손실 및 정확도 그래프
    fig, ax = plt.subplots(figsize=(10, 6))
    draw_loss_and_accuracy(ax, report['train_losses'], report['val_losses'], report['test_losses'],
                           report['train_accuracies'], report['val_accuracies'], report['test_accuracies'],
                           title=f"Best Model: {params['optimizer'].__name__} (LR={params['learning_rate']})")
    plt.show()

    # 실제 값과 예측 값 출력
    print("\nSample of Actual Values vs Predicted Values:")
    test_classes = report['y_test'].argmax(axis=1)
    predicted_classes = report['predictions'].argmax(axis=1)
    for test, predicted in zip(test_classes[:10], predicted_classes[:10]):
        print(f"Actual: {test}, Predicted: {predicted}")

########################
# 파라미터 그리드 설정

# 하이퍼파라미터 그리드 설정
# 각 하이퍼파라미터마다 2개의 옵션으로 설정
param_grid = {    
    'hidden_sizes': [[32, 16, 8], [16, 16, 16], [8, 16, 32]],
    'optimizer': [tf.train.GradientDescentOptimizer, tf.train.AdamOptimizer, tf.train.AdagradOptimizer],
    'learning_rate': [0.01, 0.001, 0.0001],
    'batch_size': [16, 32, 64],
    'epoch': [1, 2, 3]
}

########################
# 메인 실행 흐름

def main():
    # Data
    x_data, y_data, feature_names = load_csv('fetal_health.csv')
    x_train, x_val, x_test, y_train, y_val, y_test = split_data(x_data, y_data)
    data = (x_train, x_val, x_test, y_train, y_val, y_test)

    # Data Analys
    draw_data_distributions(x_train, feature_names, 'Training Data Distributions')
    draw_correlation_matrix(x_train, y_train, feature_names, title='Training Data Correlation Matrix')

    # Learning
    best_report = learn(data, param_grid)

    # Report
    generate_report(best_report)

if __name__ == "__main__":
    main()
# Out:
# 1. CSV Loading
# x_data shape: (2126, 21)
# y_data shape: (2126, 3)
# Feature names: ['baseline value', 'accelerations', 'fetal_movement', 'uterine_contractions', 'light_decelerations', 'severe_decelerations', 'prolongued_decelerations', 'abnormal_short_term_variability', 'mean_value_of_short_term_variability', 'percentage_of_time_with_abnormal_long_term_variability', 'mean_value_of_long_term_variability', 'histogram_width', 'histogram_min', 'histogram_max', 'histogram_number_of_peaks', 'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean', 'histogram_median', 'histogram_variance', 'histogram_tendency']
#
# 2. Data Analysis
# 3. Training Models
# Total configurations: 243
# Training model 1/243 with parameters:
# Config indices: (0, 0, 0, 0, 0)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.gradient_descent.GradientDescentOptimizer'>, 'learning_rate': 0.01, 'batch_size': 16, 'epoch': 1}
# Epoch 1, Training Loss: 0.8693, Training Accuracy: 0.7781, Validation Loss: 0.8695, Validation Accuracy: 0.7793, Test Loss: 0.8684, Test Accuracy: 0.7793
# New best model found: Test Accuracy = 0.7793
#
# --------------------------------------------------------------------------------
# Training model 2/243 with parameters:
# Config indices: (0, 0, 0, 0, 1)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.gradient_descent.GradientDescentOptimizer'>, 'learning_rate': 0.01, 'batch_size': 16, 'epoch': 2}
# Epoch 1, Training Loss: 0.8913, Training Accuracy: 0.7781, Validation Loss: 0.8904, Validation Accuracy: 0.7793, Test Loss: 0.8907, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 3/243 with parameters:
# Config indices: (0, 0, 0, 0, 2)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.gradient_descent.GradientDescentOptimizer'>, 'learning_rate': 0.01, 'batch_size': 16, 'epoch': 3}
# Epoch 1, Training Loss: 0.8751, Training Accuracy: 0.7781, Validation Loss: 0.8747, Validation Accuracy: 0.7793, Test Loss: 0.8740, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 4/243 with parameters:
# Config indices: (0, 0, 0, 1, 0)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.gradient_descent.GradientDescentOptimizer'>, 'learning_rate': 0.01, 'batch_size': 32, 'epoch': 1}
# Epoch 1, Training Loss: 0.9708, Training Accuracy: 0.7781, Validation Loss: 0.9704, Validation Accuracy: 0.7793, Test Loss: 0.9706, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model
 0, 2)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.001, 'batch_size': 16, 'epoch': 3}
# Epoch 1, Training Loss: 1.0811, Training Accuracy: 0.7781, Validation Loss: 1.0807, Validation Accuracy: 0.7840, Test Loss: 1.0804, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 67/243 with parameters:
# Config indices: (0, 2, 1, 1, 0)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.001, 'batch_size': 32, 'epoch': 1}
# Epoch 1, Training Loss: 1.0894, Training Accuracy: 0.7754, Validation Loss: 1.0890, Validation Accuracy: 0.7793, Test Loss: 1.0893, Test Accuracy: 0.7746
# --------------------------------------------------------------------------------
# Training model 68/243 with parameters:
# Config indices: (0, 2, 1, 1, 1)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.001, 'batch_size': 32, 'epoch': 2}
# Epoch 1, Training Loss: 1.0836, Training Accuracy: 0.7781, Validation Loss: 1.0838, Validation Accuracy: 0.7793, Test Loss: 1.0832, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 69/243 with parameters:
# Config indices: (0, 2, 1, 1, 2)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.001, 'batch_size': 32, 'epoch': 3}
# Epoch 1, Training Loss: 1.0878, Training Accuracy: 0.7915, Validation Loss: 1.0872, Validation Accuracy: 0.8028, Test Loss: 1.0877, Test Accuracy: 0.7864
# --------------------------------------------------------------------------------
# Training model 70/243 with parameters:
# Config indices: (0, 2, 1, 2, 0)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.001, 'batch_size': 64, 'epoch': 1}
# Epoch 1, Training Loss: 1.0951, Training Accuracy: 0.3618, Validation Loss: 1.0944, Validation Accuracy: 0.3944, Test Loss: 1.0951, Test Accuracy: 0.3967
# --------------------------------------------------------------------------------
# Training model 71/243 with parameters:
# Config indices: (0, 2, 1, 2, 1)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.001, 'batch_size': 64, 'epoch': 2}
# Epoch 1, Training Loss: 1.0990, Training Accuracy: 0.4048, Validation Loss: 1.0991, Validation Accuracy: 0.3944, Test Loss: 1.0986, Test Accuracy: 0.4554
# --------------------------------------------------------------------------------
# Training model 72/243 with parameters:
# Config indices: (0, 2, 1, 2, 2)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.001, 'batch_size': 64, 'epoch': 3}
# Epoch 1, Training Loss: 1.0947, Training Accuracy: 0.6530, Validation Loss: 1.0947, Validation Accuracy: 0.6244, Test Loss: 1.0944, Test Accuracy: 0.6549
# --------------------------------------------------------------------------------
# Training model 73/243 with parameters:
# Config indices: (0, 2, 2, 0, 0)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 16, 'epoch': 1}
# Epoch 1, Training Loss: 1.0953, Training Accuracy: 0.5017, Validation Loss: 1.0957, Validation Accuracy: 0.4977, Test Loss: 1.0957, Test Accuracy: 0.4953
# --------------------------------------------------------------------------------
# Training model 74/243 with parameters:
# Config indices: (0, 2, 2, 0, 1)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 16, 'epoch': 2}
# Epoch 1, Training Loss: 1.0934, Training Accuracy: 0.6772, Validation Loss: 1.0935, Validation Accuracy: 0.7089, Test Loss: 1.0936, Test Accuracy: 0.6995
# --------------------------------------------------------------------------------
# Training model 75/243 with parameters:
# Config indices: (0, 2, 2, 0, 2)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 16, 'epoch': 3}
# Epoch 1, Training Loss: 1.0968, Training Accuracy: 0.7209, Validation Loss: 1.0969, Validation Accuracy: 0.7277, Test Loss: 1.0967, Test Accuracy: 0.7324
# --------------------------------------------------------------------------------
# Training model 76/243 with parameters:
# Config indices: (0, 2, 2, 1, 0)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 32, 'epoch': 1}
# Epoch 1, Training Loss: 1.0938, Training Accuracy: 0.7344, Validation Loss: 1.0937, Validation Accuracy: 0.7089, Test Loss: 1.0936, Test Accuracy: 0.7324
# --------------------------------------------------------------------------------
# Training model 77/243 with parameters:
# Config indices: (0, 2, 2, 1, 1)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 32, 'epoch': 2}
# Epoch 1, Training Loss: 1.0975, Training Accuracy: 0.4600, Validation Loss: 1.0975, Validation Accuracy: 0.4225, Test Loss: 1.0977, Test Accuracy: 0.4272
# --------------------------------------------------------------------------------
# Training model 78/243 with parameters:
# Config indices: (0, 2, 2, 1, 2)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 32, 'epoch': 3}
# Epoch 1, Training Loss: 1.0978, Training Accuracy: 0.1775, Validation Loss: 1.0980, Validation Accuracy: 0.1925, Test Loss: 1.0976, Test Accuracy: 0.1737
# --------------------------------------------------------------------------------
# Training model 79/243 with parameters:
# Config indices: (0, 2, 2, 2, 0)
# {'hidden_sizes': [32, 16, 8], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 64, 'epoch': 1}
# Epoch 1, Training Loss: 1
Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 95/243 with parameters:
# Config indices: (1, 0, 1, 1, 1)
# {'hidden_sizes': [16, 16, 16], 'optimizer': <class 'tensorflow.python.training.gradient_descent.GradientDescentOptimizer'>, 'learning_rate': 0.001, 'batch_size': 32, 'epoch': 2}
# Epoch 1, Training Loss: 1.0807, Training Accuracy: 0.7781, Validation Loss: 1.0806, Validation Accuracy: 0.7793, Test Loss: 1.0803, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 96/243 with parameters:
# Config indices: (1, 0, 1, 1, 2)
# {'hidden_sizes': [16, 16, 16], 'optimizer': <class 'tensorflow.python.training.gradient_descent.GradientDescentOptimizer'>, 'learning_rate': 0.001, 'batch_size': 32, 'epoch': 3}
# Epoch 1, Training Loss: 1.0851, Training Accuracy: 0.7781, Validation Loss: 1.0852, Validation Accuracy: 0.7793, Test Loss: 1.0849, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 97/243 with parameters:
# Config indices: (1, 0, 1, 2, 0)
# {'hidden_sizes': [16, 16, 16], 'optimizer': <class 'tensorflow.python.training.gradient_descent.GradientDescentOptimizer'>, 'learning_rate': 0.001, 'batch_size': 64, 'epoch': 1}
# Epoch 1, Training Loss: 1.0871, Training Accuracy: 0.7781, Validation Loss: 1.0868, Validation Accuracy: 0.7793, Test Loss: 1.0864, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 98/243 with parameters:
# Config indices: (1, 0, 1, 2, 1)
# {'hidden_sizes': [16, 16, 16], 'optimizer': <class 'tensorflow.python.training.gradient_descent.GradientDescentOptimizer'>, 'learning_rate': 0.001, 'batch_size': 64, 'epoch': 2}
# Epoch 1, Training Loss: 1.0912, Training Accuracy: 0.7653, Validation Loss: 1.0910, Validation Accuracy: 0.7653, Test Loss: 1.0913, Test Accuracy: 0.7676
# --------------------------------------------------------------------------------
# Training model 99/243 with parameters:
# Config indices: (1, 0, 1, 2, 2)
# {'hidden_sizes': [16, 16, 16], 'optimizer': <class 'tensorflow.python.training.gradient_descent.GradientDescentOptimizer'>, 'learning_rate': 0.001, 'batch_size': 64, 'epoch': 3}
# Epoch 1, Training Loss: 1.0953, Training Accuracy: 0.5602, Validation Loss: 1.0951, Validation Accuracy: 0.6009, Test Loss: 1.0955, Test Accuracy: 0.5563
# --------------------------------------------------------------------------------
# Training model 100/243 with parameters:
# Config indices: (1, 0, 2, 0, 0)
# {'hidden_sizes': [16, 16, 16], 'optimizer': <class 'tensorflow.python.training.gradient_descent.GradientDescentOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 16, 'epoch': 1}
# Epoch 1, Training Loss: 1.0950, Training Accuracy: 0.7640, Validation Loss: 1.0950, Validation Accuracy: 0.7746, Test Loss: 1.0950, Test Accuracy: 0.7629
# ...
# --------------------------------------------------------------------------------
# Training model 211/243 with parameters:
# Config indices: (2, 1, 2, 1, 0)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adam.AdamOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 32, 'epoch': 1}
# Epoch 1, Training Loss: 1.0898, Training Accuracy: 0.7714, Validation Loss: 1.0897, Validation Accuracy: 0.7746, Test Loss: 1.0897, Test Accuracy: 0.7723
# --------------------------------------------------------------------------------
# Training model 212/243 with parameters:
# Config indices: (2, 1, 2, 1, 1)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adam.AdamOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 32, 'epoch': 2}
# Epoch 1, Training Loss: 1.0829, Training Accuracy: 0.7781, Validation Loss: 1.0831, Validation Accuracy: 0.7793, Test Loss: 1.0831, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 213/243 with parameters:
# Config indices: (2, 1, 2, 1, 2)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adam.AdamOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 32, 'epoch': 3}
# Epoch 1, Training Loss: 1.0863, Training Accuracy: 0.7976, Validation Loss: 1.0859, Validation Accuracy: 0.7840, Test Loss: 1.0866, Test Accuracy: 0.7911
# --------------------------------------------------------------------------------
# Training model 214/243 with parameters:
# Config indices: (2, 1, 2, 2, 0)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adam.AdamOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 64, 'epoch': 1}
# Epoch 1, Training Loss: 1.0951, Training Accuracy: 0.6900, Validation Loss: 1.0951, Validation Accuracy: 0.7089, Test Loss: 1.0949, Test Accuracy: 0.6925
# --------------------------------------------------------------------------------
# Training model 215/243 with parameters:
# Config indices: (2, 1, 2, 2, 1)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adam.AdamOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 64, 'epoch': 2}
# Epoch 1, Training Loss: 1.0929, Training Accuracy: 0.7740, Validation Loss: 1.0929, Validation Accuracy: 0.7653, Test Loss: 1.0930, Test Accuracy: 0.7770
# --------------------------------------------------------------------------------
# Training model 216/243 with parameters:
# Config indices: (2, 1, 2, 2, 2)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adam.AdamOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 64, 'epoch': 3}
# Epoch 1, Training Loss: 1.0901, Training Accuracy: 0.7781, Validation Loss: 1.0904, Validation Accuracy: 0.7793, Test Loss: 1.0903, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 217/243 with parameters:
# Config indices: (2, 2, 0, 0, 0)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.01, 'batch_size': 16, 'epoch': 1}
# Epoch 1, Training Loss: 0.8956, Training Accuracy: 0.7781, Validation Loss: 0.8954, Validation Accuracy: 0.7793, Test Loss: 0.8952, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 218/243 with parameters:
# Config indices: (2, 2, 0, 0, 1)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.01, 'batch_size': 16, 'epoch': 2}
# Epoch 1, Training Loss: 0.9151, Training Accuracy: 0.7781, Validation Loss: 0.9146, Validation Accuracy: 0.7793, Test Loss: 0.9147, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model
 0)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 16, 'epoch': 1}
# Epoch 1, Training Loss: 1.1082, Training Accuracy: 0.1399, Validation Loss: 1.1073, Validation Accuracy: 0.1596, Test Loss: 1.1085, Test Accuracy: 0.1315
# --------------------------------------------------------------------------------
# Training model 236/243 with parameters:
# Config indices: (2, 2, 2, 0, 1)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 16, 'epoch': 2}
# Epoch 1, Training Loss: 1.0961, Training Accuracy: 0.7054, Validation Loss: 1.0960, Validation Accuracy: 0.7136, Test Loss: 1.0962, Test Accuracy: 0.6854
# --------------------------------------------------------------------------------
# Training model 237/243 with parameters:
# Config indices: (2, 2, 2, 0, 2)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 16, 'epoch': 3}
# Epoch 1, Training Loss: 1.0987, Training Accuracy: 0.3988, Validation Loss: 1.0987, Validation Accuracy: 0.3521, Test Loss: 1.0985, Test Accuracy: 0.3756
# --------------------------------------------------------------------------------
# Training model 238/243 with parameters:
# Config indices: (2, 2, 2, 1, 0)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 32, 'epoch': 1}
# Epoch 1, Training Loss: 1.0958, Training Accuracy: 0.7781, Validation Loss: 1.0958, Validation Accuracy: 0.7793, Test Loss: 1.0953, Test Accuracy: 0.7793
# --------------------------------------------------------------------------------
# Training model 239/243 with parameters:
# Config indices: (2, 2, 2, 1, 1)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 32, 'epoch': 2}
# Epoch 1, Training Loss: 1.0919, Training Accuracy: 0.7714, Validation Loss: 1.0920, Validation Accuracy: 0.7746, Test Loss: 1.0914, Test Accuracy: 0.7770
# --------------------------------------------------------------------------------
# Training model 240/243 with parameters:
# Config indices: (2, 2, 2, 1, 2)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 32, 'epoch': 3}
# Epoch 1, Training Loss: 1.0932, Training Accuracy: 0.5703, Validation Loss: 1.0920, Validation Accuracy: 0.6103, Test Loss: 1.0938, Test Accuracy: 0.5657
# --------------------------------------------------------------------------------
# Training model 241/243 with parameters:
# Config indices: (2, 2, 2, 2, 0)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 64, 'epoch': 1}
# Epoch 1, Training Loss: 1.0999, Training Accuracy: 0.3443, Validation Loss: 1.1002, Validation Accuracy: 0.3568, Test Loss: 1.1000, Test Accuracy: 0.3521
# --------------------------------------------------------------------------------
# Training model 242/243 with parameters:
# Config indices: (2, 2, 2, 2, 1)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 64, 'epoch': 2}
# Epoch 1, Training Loss: 1.0980, Training Accuracy: 0.3874, Validation Loss: 1.0978, Validation Accuracy: 0.3944, Test Loss: 1.0984, Test Accuracy: 0.3826
# --------------------------------------------------------------------------------
# Training model 243/243 with parameters:
# Config indices: (2, 2, 2, 2, 2)
# {'hidden_sizes': [8, 16, 32], 'optimizer': <class 'tensorflow.python.training.adagrad.AdagradOptimizer'>, 'learning_rate': 0.0001, 'batch_size': 64, 'epoch': 3}
# Epoch 1, Training Loss: 1.0985, Training Accuracy: 0.3282, Validation Loss: 1.0986, Validation Accuracy: 0.3052, Test Loss: 1.0989, Test Accuracy: 0.2958
# --------------------------------------------------------------------------------
# 4. Conclusion
# [Best Parameters]
# Optimizer: AdamOptimizer
# Learning rate: 0.01
# Hidden sizes: [16, 16, 16]
# Batch size: 16
# Epoch: 2
# Training loss: 0.2680
# Validation loss: 0.3033
# Test loss: 0.3210
# Test Accuracy: 0.8685
# Sample of Actual Values vs Predicted Values:
# Actual: 0, Predicted: 0
# Actual: 0, Predicted: 0
# Actual: 0, Predicted: 0
# Actual: 0, Predicted: 0
# Actual: 0, Predicted: 0
# Actual: 0, Predicted: 0
# Actual: 0, Predicted: 0
# Actual: 0, Predicted: 0
# Actual: 0, Predicted: 0
# Actual: 0, Predicted: 0
